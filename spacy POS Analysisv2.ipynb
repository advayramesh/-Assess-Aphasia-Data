# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")
#DOCNAME = nlp("I see on the left side a young lady reaching for a cookie and her brother's about to fall off the getting into the jar. I see Mom washing and she's looking out the window and the water's falling all over the that's about it")

# parts of speech tagging
# for token in DOCNAME:
#     print(((token.text,
#             token.lemma_,
#             token.pos_,
#             token.tag_,
#             token.dep_,
#             token.shape_,
#             token.is_alpha,
#             token.is_stop,
#             )))
# for token in doc:
#     print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
#             token.shape_, token.is_alpha, token.is_stop)

# %%
#Initialize array (columns for excel)

Group = []
Type = []
Key = []
Text = []
Freq = []

LHD = ""
RHD = ""

Debug = 0;

# %%
def pos_dep_parsing(chunk):
# To print the text, Part of Speech, Dependancy of tokens
# for token in DOCNAME:
#     print(token.text,token.pos_, token.dep_)

  DOCNAME = nlp(chunk)
  #Part of speech where k = key value assigned by spaCy and f = frequency and DOCNAME is whatever you have called your document
  POS_counts = DOCNAME.count_by(spacy.attrs.POS)
  POS_counts


  if ( Debug == 1 ):
    print("Part of speech and frequency")
    for k, f in sorted(POS_counts.items()):
      print(f'{k}. {DOCNAME.vocab[k].text:{10}}:{f}')

  for k, f in sorted(POS_counts.items()):
    #print(f'{k}. {DOCNAME.vocab[k].text:{10}}:{f}')
    Group.append(group)
    Type.append('POS')
    Key.append(k)
    Text.append(DOCNAME.vocab[k].text)
    Freq.append(f)


  #Dependencies where k = key value and f = frequency and DOCNAME is whatever you have called your document
  DEP_counts = DOCNAME.count_by(spacy.attrs.DEP)
  DEP_counts

  if ( Debug == 1 ):
    print("Dependencies and frequency")
    for k, f in sorted(DEP_counts.items()):
      print(f'{k}. {DOCNAME.vocab[k].text:{10}}:{f}')


  for k, f in sorted(DEP_counts.items()):
    #print(f'{k}. {DOCNAME.vocab[k].text:{10}}:{f}')
    Group.append(group)
    Type.append("DEP")
    Key.append(k)
    Text.append(DOCNAME.vocab[k].text)
    Freq.append(f)

# %%
#Read file
def read_and_split_file(file_path, delimiter):
    with open(file_path, 'r') as file:
        content = file.read()
        chunks = content.split(delimiter)
        return chunks

file_path = "/content/Cookie Theft all speech.txt"
delimiter = "----------------------------------------------------"
type_len = 3
lhd = 0
rhd = 0
others = 0

chunks = read_and_split_file(file_path, delimiter)
for index, chunk in enumerate(chunks):
  chunk = chunk.strip()
  type = chunk[:type_len]
  describe = (chunk[type_len:].strip())
  if ( type == "LHD"):
    lhd = lhd + 1
    LHD = LHD + describe
    group = "LHD"+ str(index+1)
  elif (type == "RHD"):
    rhd = rhd + 1
    RHD = RHD + describe
    group = "RHD"+ str(index+1)
  else:
    others = others + 1
  pos_dep_parsing(describe)

# %%
#Do all LHD, RHD as full group

group = "LHDA"
pos_dep_parsing(LHD)
group = "RHDA"
pos_dep_parsing(RHD)

# %%
# Write to excel file
import pandas as pd
Dataset = pd.DataFrame()
Dataset['Group'] = Group
Dataset['Type'] = Type
Dataset['Key'] = Key
Dataset['Text'] = Text
Dataset['Freq'] = Freq


Dataset
#Dataset.to_csv('Aphasia_POS_DEP_Freq.csv')
# Out:
#      Group Type                   Key      Text  Freq
# 0     LHD1  POS                    84       ADJ     2
# 1     LHD1  POS                    85       ADP     8
# 2     LHD1  POS                    86       ADV     1
# 3     LHD1  POS                    87       AUX     2
# 4     LHD1  POS                    89     CCONJ     3
# ...    ...  ...                   ...       ...   ...
# 2612  RHDA  DEP   7037928807040764755  compound    27
# 2613  RHDA  DEP   8110129090154140942      case    10
# 2614  RHDA  DEP   8206900633647566924      ROOT    55
# 2615  RHDA  DEP  12837356684637874264    nummod     9
# 2616  RHDA  DEP  13323405159917154080    predet     1
#
# [2617 rows x 5 columns]

# %%
Dataset.to_csv('Aphasia_POS_DEP_Freq.csv')
